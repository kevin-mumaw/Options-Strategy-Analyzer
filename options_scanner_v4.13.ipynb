# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin-mumaw/Options-Strategy-Analyzer/blob/main/options_scanner_v4.13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Options Scanner v4 — Phase 1
#
# **CALL-side scanner with quality scoring gate**
#
# A signal is only generated when conviction score >= 6/10.
# If nothing qualifies, the scanner tells you to wait.
# Every signal includes exact entry, stop, target, and time stop.
#
# ---
#
# | Score | Conviction | Action |
# |-------|------------|--------|
# | 9-10  | VERY HIGH  | Strong candidate |
# | 7-8   | HIGH       | Good candidate |
# | 6     | MODERATE   | Minimum threshold — smaller size |
# | < 6   | NONE       | No signal — wait |
#
# **Scoring breakdown (10 pts total):**
# Regime (2) + RSI (2) + Trend (2) + Volume (2) + Weekly (1) + Support (1)

# %%
# Cell 1 — Install dependencies
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                'yfinance', 'pandas', 'numpy', 'matplotlib', 'scipy'])
print('Dependencies ready')
# Out:
# Dependencies ready

# %%
# ─────────────────────────────────────────────────────────────
# FORCE RELOAD CELL — run this whenever options_scanner_v4.py
# is updated on GitHub. DO NOT DELETE.
# ─────────────────────────────────────────────────────────────
import sys, os, time

if 'options_scanner_v4' in sys.modules:
    del sys.modules['options_scanner_v4']
if os.path.exists('options_scanner_v4.py'):
    os.remove('options_scanner_v4.py')

url = f"https://raw.githubusercontent.com/kevin-mumaw/options-strategy-analyzer/main/options_scanner_v4.py?t={int(time.time())}"
# !wget -q -O options_scanner_v4.py "{url}"

# Verify correct version loaded
with open('options_scanner_v4.py') as f:
    content = f.read()

checks = ['target_width', 'min_reward_risk', '2.0', 'also_qualified', 'hard_fail']
for c in checks:
    print(f"{'✓' if c in content else '✗'} {c}")

from options_scanner_v4 import run_scan, print_results, deep_dive, ALL_SYMBOLS, CONFIG, find_best_call
print('\n✓ Scanner reloaded successfully')
# Out:
# ✓ target_width
# ✓ min_reward_risk
# ✓ 2.0
# ✓ also_qualified
# ✓ hard_fail
#
# ✓ Scanner reloaded successfully

# %%
# Cell 2 — Load scanner from GitHub
# Replace YOUR_USERNAME with kevin-mumaw
# !wget -q https://raw.githubusercontent.com/kevin-mumaw/options-strategy-analyzer/main/options_scanner_v4.py

from options_scanner_v4 import (
    run_scan, print_results, deep_dive,
    ALL_SYMBOLS, WATCHLIST, CONFIG
)
print('Scanner loaded')
print(f'Watchlist: {len(ALL_SYMBOLS)} symbols')
print('Groups:', list(WATCHLIST.keys()))
# Out:
# Scanner loaded
# Watchlist: 34 symbols
# Groups: ['tier1_affordable', 'tier2_sweet_spot', 'tier3_mid_price', 'tier4_high_price']

# %%
# Cell 3 — Configure
# Edit account size here. Everything else auto-adjusts.

MY_CONFIG = {**CONFIG}  # copy defaults

MY_CONFIG['account_size'] = 5000.00  # update as your account grows

# Optional: scan only specific symbols instead of full watchlist
# MY_SYMBOLS = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'NVDA', 'JPM']
MY_SYMBOLS = None  # None = scan all 25 symbols

print(f'Account: ${MY_CONFIG["account_size"]:,.0f}')
print(f'Min score to generate signal: {MY_CONFIG["min_score"]}/10')
print(f'Stop loss: -{int(MY_CONFIG["stop_loss_pct"]*100)}% | '
      f'Profit target: +{int(MY_CONFIG["profit_target_pct"]*100)}% | '
      f'Time stop: {MY_CONFIG["time_stop_dte"]} DTE')
# Out:
# Account: $5,000
# Min score to generate signal: 6/10
# Stop loss: -35% | Profit target: +75% | Time stop: 21 DTE

# %%
# Cell 4 — Run the scan
# This is the main cell. Run this daily.
results = run_scan(symbols=MY_SYMBOLS, config=MY_CONFIG)
print_results(results)
# Out:
#   Fetching market regime (QQQ)...
#   Regime: BULLISH — QQQ 717.54 | MA50 642.01 (+11.8%) | MA200 613.6 (+16.9%)
#
#   Scanning 34 symbols.................................. done.
#
#
# ██████████████████████████████████████████████████████████████
#   OPTIONS SCANNER — Phase 1  v4.13  |  2026-05-25 02:04
#   Account: $5,000  |  Scanned: 34 symbols
# ██████████████████████████████████████████████████████████████
#
#   MARKET REGIME: 🟢 BULLISH
#   QQQ 717.54 | MA50 642.01 (+11.8%) | MA200 613.6 (+16.9%)
#
#   3 signal(s) found:
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #1  |  BAC — BUY CALL  |  Score: 7/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ~ RSI     [1/2] Neutral — RSI 48 (room to run)
#     ✓ Trend   [2/2] Clean uptrend — price > MA20 > MA50
#     ~ Weekly  [0/1] Weekly trend mixed
#     ~ Volume  [1/2] Mild accumulation — 2/5 up days on above-avg volume
#     ✓ Support [1/1] Near MA50 support (+1.9%)
#     ✗ MACD    [0/1] Bearish — MACD -0.201 below signal -0.152
#     ~ BB      [0/1] Mid-range (BB% 0.51)
#
#   STOCK:
#     Price: $51.80   RSI: 48   Trend: UPTREND
#     MA20:  $51.73 (+0.1%)   MA50: $50.84 (+1.9%)
#     HV30:  19.5%   Weekly: MIXED
#     Earnings:  2026-07-14 (50 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $50 CALL  |  53 DTE
#     Bid: $3.25  Ask: $3.35  Mid: $3.30  Spread: 3.0%
#     IV: 30.0%  |  Delta: 0.664  |  Theta: $-2.40/day  |  Vol: 264  OI: 6714
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $335  (6.7% of account)
#     Reward/Risk: 2.1x  (risking $1.17 to make $2.51)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $2.18  (-35%)
#     ├─ Profit target : Sell if premium reaches $5.86  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #2  |  XLF — BUY CALL  |  Score: 7/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ~ RSI     [1/2] Neutral — RSI 54 (room to run)
#     ✓ Trend   [2/2] Clean uptrend — price > MA20 > MA50
#     ~ Weekly  [0/1] Weekly trend mixed
#     ~ Volume  [1/2] Neutral volume — no clear institutional signal
#     ✓ Support [1/1] Near MA50 support (+2.2%)
#     ✗ MACD    [0/1] Bearish — MACD 0.102 below signal 0.107
#     ✗ BB      [0/1] Near upper band — extended (BB% 0.77)
#
#   STOCK:
#     Price: $51.94   RSI: 54   Trend: UPTREND
#     MA20:  $51.59 (+0.7%)   MA50: $50.80 (+2.2%)
#     HV30:  11.4%   Weekly: MIXED
#
#   OPTION:
#     2026-07-17 $51 CALL  |  53 DTE
#     Bid: $1.90  Ask: $2.11  Mid: $2.00  Spread: 10.0%
#     IV: 20.2%  |  Delta: 0.641  |  Theta: $-1.80/day  |  Vol: 63  OI: 1295
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $211  (4.2% of account)
#     Reward/Risk: 2.1x  (risking $0.74 to make $1.58)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $1.37  (-35%)
#     ├─ Profit target : Sell if premium reaches $3.69  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #3  |  PFE — BUY CALL  |  Score: 6/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ~ RSI     [1/2] Neutral — RSI 51 (room to run)
#     ✗ Trend   [0/2] Mixed with price below MA50
#     ~ Weekly  [0/1] Weekly trend mixed
#     ~ Volume  [1/2] Neutral volume — no clear institutional signal
#     ✓ Support [1/1] Near MA50 support (-2.1%)
#     ✓ MACD    [1/1] Bullish — MACD -0.205 above signal -0.241
#     ~ BB      [0/1] Mid-range (BB% 0.53)
#
#   STOCK:
#     Price: $25.90   RSI: 51   Trend: MIXED
#     MA20:  $25.87 (+0.1%)   MA50: $26.46 (-2.1%)
#     HV30:  15.2%   Weekly: MIXED
#     Earnings:  2026-07-29 (65 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $25 CALL  |  53 DTE
#     Bid: $1.46  Ask: $1.70  Mid: $1.58  Spread: 14.1%
#     IV: 30.7%  |  Delta: 0.662  |  Theta: $-1.20/day  |  Vol: 118  OI: 923
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $170  (3.4% of account)
#     Reward/Risk: 2.1x  (risking $0.60 to make $1.28)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $1.10  (-35%)
#     ├─ Profit target : Sell if premium reaches $2.98  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ──────────────────────────────────────────────────────────────
#   DISQUALIFIED — do not chase:
#     COST    9/10 — ⚠ Earnings in 3 days (2026-05-28) — avoid new entries
#     AAL     7/10 — Overbought (RSI 71) AND extended (+18.3% above MA50) — do not chase
#     KO      7/10 — RSI 76 — severely overbought, wait for pullback
#     AAPL    7/10 — Overbought (RSI 91) AND extended (+14.2% above MA50) — do not chase
#     GS      7/10 — Overbought (RSI 74) AND extended (+11.2% above MA50) — do not chase
# ──────────────────────────────────────────────────────────────
#   NEAR MISSES (score 5/10 — one more factor could qualify):
#     NKE     5/10  Trend: MIXED       RSI: 61.3
#     META    5/10  Trend: MIXED       RSI: 49.9
# ──────────────────────────────────────────────────────────────
#   OPTION FOUND — FAILED 2:1 REWARD/RISK (+ 8 more):
#     V       8/10  R/R: 1.2x — wait for pullback or lower IV
#     XOM     8/10  R/R: 1.4x — wait for pullback or lower IV
#     C       7/10  R/R: 1.3x — wait for pullback or lower IV
#     JPM     7/10  R/R: 1.0x — wait for pullback or lower IV
#     CVX     7/10  R/R: 1.1x — wait for pullback or lower IV
# ──────────────────────────────────────────────────────────────
#   SCAN COMPLETE  |  3 signal(s)  |  34 symbols scanned
#   Remember: No trade is always a valid choice.

# %%
# Cell 5 — Deep dive on a specific symbol
# Use this to investigate any symbol in detail,
# whether it appeared in the scan or not.

SYMBOL = 'bac'  # change this

deep_dive(SYMBOL, config=MY_CONFIG)
# Out:
#   Fetching regime and analyzing bac...
#
# ██████████████████████████████████████████████████████████████
#   OPTIONS SCANNER — Phase 1  v4.13  |  2026-05-25 02:05
#   Account: $5,000  |  Scanned: 1 symbols
# ██████████████████████████████████████████████████████████████
#
#   MARKET REGIME: 🟢 BULLISH
#   QQQ 717.54 | MA50 642.01 (+11.8%) | MA200 613.6 (+16.9%)
#
#   1 signal(s) found:
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #1  |  bac — BUY CALL  |  Score: 7/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ~ RSI     [1/2] Neutral — RSI 48 (room to run)
#     ✓ Trend   [2/2] Clean uptrend — price > MA20 > MA50
#     ~ Weekly  [0/1] Weekly trend mixed
#     ~ Volume  [1/2] Mild accumulation — 2/5 up days on above-avg volume
#     ✓ Support [1/1] Near MA50 support (+1.9%)
#     ✗ MACD    [0/1] Bearish — MACD -0.201 below signal -0.152
#     ~ BB      [0/1] Mid-range (BB% 0.51)
#
#   STOCK:
#     Price: $51.80   RSI: 48   Trend: UPTREND
#     MA20:  $51.73 (+0.1%)   MA50: $50.84 (+1.9%)
#     HV30:  19.5%   Weekly: MIXED
#     Earnings:  2026-07-14 (50 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $50 CALL  |  53 DTE
#     Bid: $3.25  Ask: $3.35  Mid: $3.30  Spread: 3.0%
#     IV: 30.0%  |  Delta: 0.664  |  Theta: $-2.40/day  |  Vol: 264  OI: 6714
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $335  (6.7% of account)
#     Reward/Risk: 2.1x  (risking $1.17 to make $2.51)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $2.18  (-35%)
#     ├─ Profit target : Sell if premium reaches $5.86  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ──────────────────────────────────────────────────────────────
#   SCAN COMPLETE  |  1 signal(s)  |  1 symbols scanned
#   Remember: No trade is always a valid choice.

# %%
# Cell 6 — Review all scores from last scan
# See every symbol's score ranked highest to lowest.

import pandas as pd

rows = []
for r in results['all_results']:
    if not r.get('error'):
        rows.append({
            'Symbol':    r['symbol'],
            'Score':     r['score'],
            'Conviction':r['conviction'],
            'Trend':     r.get('trend','—'),
            'RSI':       r.get('rsi','—'),
            'Volume':    r.get('vol_data',{}).get('label','—'),
            'Weekly':    r.get('weekly',{}).get('trend','—'),
            'Has Option':r.get('option') is not None,
        })

df = pd.DataFrame(rows).sort_values('Score', ascending=False)
print(df.to_string(index=False))
# Out:
# Symbol  Score Conviction     Trend  RSI            Volume    Weekly  Has Option
#   COST      9       HIGH   UPTREND 53.6           NEUTRAL   UPTREND       False
#      V      8       HIGH   UPTREND 52.9           NEUTRAL     MIXED       False
#    XOM      8       HIGH     MIXED 53.0           NEUTRAL   UPTREND       False
#    BAC      7   MODERATE   UPTREND 47.5 MILD_ACCUMULATION     MIXED        True
#    AAL      7   MODERATE   UPTREND 71.4      ACCUMULATION     MIXED       False
#    XLF      7   MODERATE   UPTREND 54.0           NEUTRAL     MIXED        True
#     KO      7   MODERATE   UPTREND 75.7           NEUTRAL   UPTREND       False
#      C      7   MODERATE     MIXED 48.8           NEUTRAL   UPTREND       False
#   AAPL      7   MODERATE   UPTREND 91.1           NEUTRAL   UPTREND       False
#    JPM      7   MODERATE   UPTREND 48.8           NEUTRAL     MIXED       False
#    CVX      7   MODERATE     MIXED 51.3           NEUTRAL   UPTREND       False
#    JNJ      7   MODERATE     MIXED 68.0           NEUTRAL   UPTREND       False
#     GS      7   MODERATE   UPTREND 73.7 MILD_ACCUMULATION   UPTREND       False
#      F      6   MODERATE   UPTREND 75.5           NEUTRAL     MIXED       False
#    PFE      6   MODERATE     MIXED 50.6           NEUTRAL     MIXED        True
#    DIS      6   MODERATE     MIXED 53.4           NEUTRAL     MIXED       False
#   UBER      6   MODERATE     MIXED 44.2           NEUTRAL DOWNTREND       False
#    AMD      6   MODERATE   UPTREND 75.2           NEUTRAL   UPTREND       False
#   INTC      6   MODERATE   UPTREND 66.2           NEUTRAL   UPTREND       False
#     MU      6   MODERATE   UPTREND 66.2           NEUTRAL   UPTREND       False
#  GOOGL      6   MODERATE     MIXED 49.8           NEUTRAL   UPTREND       False
#    UNH      6   MODERATE   UPTREND 62.9           NEUTRAL   UPTREND       False
#   MSFT      6   MODERATE   UPTREND 55.1           NEUTRAL     MIXED       False
#   AMZN      6   MODERATE     MIXED 43.3           NEUTRAL   UPTREND       False
#   NVDA      6   MODERATE   UPTREND 62.5           NEUTRAL   UPTREND       False
#    SPY      6   MODERATE   UPTREND 71.8           NEUTRAL   UPTREND       False
#    QQQ      6   MODERATE   UPTREND 73.5           NEUTRAL   UPTREND       False
#    NKE      5       NONE     MIXED 61.3           NEUTRAL DOWNTREND       False
#   META      5       NONE     MIXED 49.9           NEUTRAL DOWNTREND       False
#   PLTR      4       NONE DOWNTREND 35.7           NEUTRAL DOWNTREND       False
#      T      4       NONE DOWNTREND 40.2           NEUTRAL     MIXED       False
#    WFC      4       NONE DOWNTREND 42.0           NEUTRAL DOWNTREND       False
#     MA      4       NONE DOWNTREND 45.4           NEUTRAL     MIXED       False
#   SOFI      3       NONE DOWNTREND 43.8           NEUTRAL DOWNTREND       False
