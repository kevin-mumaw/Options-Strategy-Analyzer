# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin-mumaw/Options-Strategy-Analyzer/blob/main/options_scanner_v4.16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Options Scanner v4 — Phase 1
#
# **CALL-side scanner with quality scoring gate**
#
# A signal is only generated when conviction score >= 6/10.
# If nothing qualifies, the scanner tells you to wait.
# Every signal includes exact entry, stop, target, and time stop.
#
# ---
#
# | Score | Conviction | Action |
# |-------|------------|--------|
# | 9-10  | VERY HIGH  | Strong candidate |
# | 7-8   | HIGH       | Good candidate |
# | 6     | MODERATE   | Minimum threshold — smaller size |
# | < 6   | NONE       | No signal — wait |
#
# **Scoring breakdown (10 pts total):**
# Regime (2) + RSI (2) + Trend (2) + Volume (2) + Weekly (1) + Support (1)

# %%
# Cell 1 — Install dependencies
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                'yfinance', 'pandas', 'numpy', 'matplotlib', 'scipy'])
print('Dependencies ready')
# Out:
# Dependencies ready

# %%
# ─────────────────────────────────────────────────────────────
# FORCE RELOAD CELL — run this whenever options_scanner_v4.py
# is updated on GitHub. DO NOT DELETE.
# ─────────────────────────────────────────────────────────────
import sys, os, time

if 'options_scanner_v4' in sys.modules:
    del sys.modules['options_scanner_v4']
if os.path.exists('options_scanner_v4.py'):
    os.remove('options_scanner_v4.py')

url = f"https://raw.githubusercontent.com/kevin-mumaw/options-strategy-analyzer/main/options_scanner_v4.py?t={int(time.time())}"
# !wget -q -O options_scanner_v4.py "{url}"

# Verify correct version loaded
with open('options_scanner_v4.py') as f:
    content = f.read()

checks = ['target_width', 'min_reward_risk', '2.0', 'also_qualified', 'hard_fail']
for c in checks:
    print(f"{'✓' if c in content else '✗'} {c}")

from options_scanner_v4 import run_scan, print_results, deep_dive, ALL_SYMBOLS, CONFIG, find_best_call
print('\n✓ Scanner reloaded successfully')
# Out:
# ✓ target_width
# ✓ min_reward_risk
# ✓ 2.0
# ✓ also_qualified
# ✓ hard_fail
#
# ✓ Scanner reloaded successfully

# %%
# Cell 2 — Load scanner from GitHub
# Replace YOUR_USERNAME with kevin-mumaw
# !wget -q https://raw.githubusercontent.com/kevin-mumaw/options-strategy-analyzer/main/options_scanner_v4.py

from options_scanner_v4 import (
    run_scan, print_results, deep_dive,
    ALL_SYMBOLS, WATCHLIST, CONFIG
)
print('Scanner loaded')
print(f'Watchlist: {len(ALL_SYMBOLS)} symbols')
print('Groups:', list(WATCHLIST.keys()))
# Out:
# Scanner loaded
# Watchlist: 34 symbols
# Groups: ['tier1_affordable', 'tier2_sweet_spot', 'tier3_mid_price', 'tier4_high_price']

# %%
# Cell 3 — Configure
# Edit account size here. Everything else auto-adjusts.

MY_CONFIG = {**CONFIG}  # copy defaults

MY_CONFIG['account_size'] = 5000.00  # update as your account grows

# Optional: scan only specific symbols instead of full watchlist
# MY_SYMBOLS = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'NVDA', 'JPM']
MY_SYMBOLS = None  # None = scan all 25 symbols

print(f'Account: ${MY_CONFIG["account_size"]:,.0f}')
print(f'Min score to generate signal: {MY_CONFIG["min_score"]}/10')
print(f'Stop loss: -{int(MY_CONFIG["stop_loss_pct"]*100)}% | '
      f'Profit target: +{int(MY_CONFIG["profit_target_pct"]*100)}% | '
      f'Time stop: {MY_CONFIG["time_stop_dte"]} DTE')
# Out:
# Account: $5,000
# Min score to generate signal: 6/10
# Stop loss: -35% | Profit target: +75% | Time stop: 21 DTE

# %%
# Cell 4 — Run the scan
# This is the main cell. Run this daily.
results = run_scan(symbols=MY_SYMBOLS, config=MY_CONFIG)
print_results(results)
# Out:
#   Fetching market regime (QQQ)...
#   Regime: BULLISH — QQQ 729.45 | MA50 647.36 (+12.7%) | MA200 615.2 (+18.6%)
#
#   Scanning 34 symbols.................................. done.
#
#
# ██████████████████████████████████████████████████████████████
#   OPTIONS SCANNER — Phase 1  v4.16  |  2026-05-27 17:38 ET
#   Account: $5,000  |  Scanned: 34 symbols
# ██████████████████████████████████████████████████████████████
#
#   MARKET REGIME: 🟢 BULLISH
#   QQQ 729.45 | MA50 647.36 (+12.7%) | MA200 615.2 (+18.6%)
#
#   📋 Market extended above MA50 — proceed only with highest conviction setups
#
#   5 signal(s) found:
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #1  |  BAC — BUY CALL  |  Score: 8/10  [HIGH]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ✓ RSI     [2/2] Oversold — RSI 34 (potential reversal)
#     ~ Trend   [1/2] Mixed but above MA50 support
#     ~ Weekly  [0/1] Weekly trend mixed
#     ~ Volume  [1/2] Neutral volume — no clear institutional signal
#     ✓ Support [1/1] Near MA50 support (+0.1%)
#     ✓ MACD    [1/1] Bullish — MACD -0.125 above signal -0.140
#     ~ BB      [0/1] Mid-range (BB% 0.39)
#
#   STOCK:
#     Price: $51.10   RSI: 34   Trend: MIXED
#     MA20:  $51.63 (-1.0%)   MA50: $51.03 (+0.1%)
#     HV30:  20.0%   Weekly: MIXED
#     Earnings:  2026-07-14 (48 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $50 CALL  |  51 DTE
#     Bid: $2.81  Ask: $2.87  Mid: $2.84  Spread: 2.1%
#     IV: 29.9%  |  Delta: 0.62  |  Theta: $-2.50/day  |  Vol: 354  OI: 6757
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $287  (5.7% of account)
#     Reward/Risk: 2.1x  (risking $1.00 to make $2.15)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $1.87  (-35%)
#     ├─ Profit target : Sell if premium reaches $5.02  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #2  |  KO — BUY CALL  |  Score: 7/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ✗ RSI     [0/2] Overbought — RSI 66 (chasing)
#     ✓ Trend   [2/2] Clean uptrend — price > MA20 > MA50
#     ✓ Weekly  [1/1] Weekly uptrend confirmed
#     ~ Volume  [1/2] Neutral volume — no clear institutional signal
#     ~ Support [0/1] Not near key support (+5.2% from MA50)
#     ✓ MACD    [1/1] Bullish — MACD 1.152 above signal 1.094
#     ✗ BB      [0/1] Near upper band — extended (BB% 0.82)
#
#   STOCK:
#     Price: $81.62   RSI: 66   Trend: UPTREND
#     MA20:  $79.93 (+2.1%)   MA50: $77.58 (+5.2%)
#     HV30:  17.2%   Weekly: UPTREND
#     Earnings:  2026-07-21 (55 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $80 CALL  |  51 DTE
#     Bid: $3.05  Ask: $3.15  Mid: $3.10  Spread: 3.2%
#     IV: 18.5%  |  Delta: 0.661  |  Theta: $-2.60/day  |  Vol: 330  OI: 11396
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $315  (6.3% of account)
#     Reward/Risk: 2.1x  (risking $1.10 to make $2.36)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $2.05  (-35%)
#     ├─ Profit target : Sell if premium reaches $5.51  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #3  |  DIS — BUY CALL  |  Score: 7/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ~ RSI     [1/2] Neutral — RSI 39 (room to run)
#     ✓ Trend   [2/2] Clean uptrend — price > MA20 > MA50
#     ~ Weekly  [0/1] Weekly trend mixed
#     ~ Volume  [1/2] Neutral volume — no clear institutional signal
#     ✓ Support [1/1] Near MA50 support (+2.6%)
#     ✗ MACD    [0/1] Bearish — MACD 0.301 below signal 0.575
#     ~ BB      [0/1] Mid-range (BB% 0.50)
#
#   STOCK:
#     Price: $104.18   RSI: 39   Trend: UPTREND
#     MA20:  $104.15 (+0.0%)   MA50: $101.51 (+2.6%)
#     HV30:  30.1%   Weekly: MIXED
#     Earnings:  2026-08-05 (70 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $105 CALL  |  51 DTE
#     Bid: $3.50  Ask: $3.65  Mid: $3.58  Spread: 4.1%
#     IV: 25.7%  |  Delta: 0.513  |  Theta: $-4.50/day  |  Vol: 238  OI: 4766
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $365  (7.3% of account)
#     Reward/Risk: 2.1x  (risking $1.28 to make $2.74)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $2.37  (-35%)
#     ├─ Profit target : Sell if premium reaches $6.39  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #4  |  PFE — BUY CALL  |  Score: 6/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ~ RSI     [1/2] Neutral — RSI 52 (room to run)
#     ✗ Trend   [0/2] Mixed with price below MA50
#     ~ Weekly  [0/1] Weekly trend mixed
#     ~ Volume  [1/2] Neutral volume — no clear institutional signal
#     ✓ Support [1/1] Near MA50 support (-0.9%)
#     ✓ MACD    [1/1] Bullish — MACD -0.143 above signal -0.213
#     ✗ BB      [0/1] Near upper band — extended (BB% 0.87)
#
#   STOCK:
#     Price: $26.21   RSI: 52   Trend: MIXED
#     MA20:  $25.86 (+1.4%)   MA50: $26.46 (-0.9%)
#     HV30:  14.9%   Weekly: MIXED
#     Earnings:  2026-07-29 (63 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $26 CALL  |  51 DTE
#     Bid: $1.05  Ask: $1.12  Mid: $1.08  Spread: 6.3%
#     IV: 25.7%  |  Delta: 0.578  |  Theta: $-1.10/day  |  Vol: 3256  OI: 8566
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $112  (2.2% of account)
#     Reward/Risk: 2.1x  (risking $0.39 to make $0.84)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $0.73  (-35%)
#     ├─ Profit target : Sell if premium reaches $1.96  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SIGNAL #5  |  SOFI — BUY CALL  |  Score: 6/10  [MODERATE]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   WHY THIS TRADE:
#     ✓ Regime [2/2] BULLISH — QQQ above both MAs
#     ~ RSI     [1/2] Neutral — RSI 49 (room to run)
#     ✗ Trend   [0/2] Mixed with price below MA50
#     ✗ Weekly  [0/1] Weekly trend not supportive
#     ~ Volume  [1/2] Neutral volume — no clear institutional signal
#     ✓ Support [1/1] Near MA50 support (-3.2%)
#     ✓ MACD    [1/1] Bullish — MACD -0.394 above signal -0.466
#     ~ BB      [0/1] Mid-range (BB% 0.72)
#
#   STOCK:
#     Price: $16.17   RSI: 49   Trend: MIXED
#     MA20:  $15.87 (+1.9%)   MA50: $16.70 (-3.2%)
#     HV30:  63.0%   Weekly: DOWNTREND
#     Earnings:  2026-07-28 (62 days away — outside 14-day window)
#
#   OPTION:
#     2026-07-17 $16 CALL  |  51 DTE
#     Bid: $1.48  Ask: $1.52  Mid: $1.50  Spread: 2.6%
#     IV: 58.5%  |  Delta: 0.574  |  Theta: $-1.50/day  |  Vol: 6804  OI: 20358
#
#   POSITION ($5,000 account):
#     Type      : Single leg CALL
#     Contracts : 1
#     Cost      : $152  (3.0% of account)
#     Reward/Risk: 2.1x  (risking $0.53 to make $1.14)
#
#   EXIT RULES — follow these exactly:
#     ┌─ Stop loss     : Sell if premium drops to $0.99  (-35%)
#     ├─ Profit target : Sell if premium reaches $2.66  (+75%)
#     └─ Time stop     : Exit by Jun 26 (21 DTE remaining)
#
# ──────────────────────────────────────────────────────────────
#   DISQUALIFIED — do not chase:
#     AAL     7/10 — Overbought (RSI 71) AND extended (+25.5% above MA50) — do not chase
#     AMD     7/10 — Overbought (RSI 67) AND extended (+57.1% above MA50) — do not chase
#     MU      7/10 — Overbought (RSI 71) AND extended (+72.5% above MA50) — do not chase
#     AAPL    7/10 — Overbought (RSI 87) AND extended (+14.0% above MA50) — do not chase
#     GS      7/10 — Overbought (RSI 68) AND extended (+10.2% above MA50) — do not chase
# ──────────────────────────────────────────────────────────────
#   ALSO QUALIFIED (scored 6+/10 — cut off by 5-signal cap):
#     XLF     6/10  Trend: MIXED       RSI: 45.6    $51 2026-07-17 ask $1.85
# ──────────────────────────────────────────────────────────────
#   NEAR MISSES (score 5/10 — one more factor could qualify):
#     NKE     5/10  Trend: MIXED       RSI: 64.1
#     JPM     5/10  Trend: MIXED       RSI: 35.3
#     JNJ     5/10  Trend: MIXED       RSI: 63.4
#     COST    5/10  Trend: MIXED       RSI: 51.8
# ──────────────────────────────────────────────────────────────
#   OPTION FOUND — FAILED 2:1 REWARD/RISK (+ 5 more):
#     UBER    7/10  R/R: 1.9x — wait for pullback or lower IV
#     C       7/10  R/R: 1.4x — wait for pullback or lower IV
#     AMZN    7/10  R/R: 1.2x — wait for pullback or lower IV
#     GOOGL   6/10  R/R: 1.3x — wait for pullback or lower IV
#     V       6/10  R/R: 1.4x — wait for pullback or lower IV
# ──────────────────────────────────────────────────────────────
#   SCAN COMPLETE  |  5 signal(s)  |  34 symbols scanned
#   Remember: No trade is always a valid choice.

# %%
# Cell 5 — Deep dive on a specific symbol
# Use this to investigate any symbol in detail,
# whether it appeared in the scan or not.

SYMBOL = 'bac'  # change this

deep_dive(SYMBOL, config=MY_CONFIG)
# Out:
#   Fetching regime and analyzing bac...
#
# ██████████████████████████████████████████████████████████████
#   OPTIONS SCANNER — Phase 1  v4.16  |  2026-05-27 13:08
#   Account: $5,000  |  Scanned: 1 symbols
# ██████████████████████████████████████████████████████████████
#
#   MARKET REGIME: 🟢 BULLISH
#   QQQ 730.28 | MA50 644.76 (+13.3%) | MA200 614.41 (+18.9%)
#
#   📋 Market extended above MA50 — proceed only with highest conviction setups
#
# ──────────────────────────────────────────────────────────────
#   NO QUALIFYING SETUPS TODAY
#   Recommendation: Wait. Do not force a trade.
#
#   Best scores today:
#     bac     9/10  Trend: UPTREND     RSI: 43.6
#
#   Qualified but no liquid options:
#     bac     9/10 — no qualifying option
#
# ──────────────────────────────────────────────────────────────

# %%
# Cell 6 — Review all scores from last scan
# See every symbol's score ranked highest to lowest.

import pandas as pd

rows = []
for r in results['all_results']:
    if not r.get('error'):
        rows.append({
            'Symbol':    r['symbol'],
            'Score':     r['score'],
            'Conviction':r['conviction'],
            'Trend':     r.get('trend','—'),
            'RSI':       r.get('rsi','—'),
            'Volume':    r.get('vol_data',{}).get('label','—'),
            'Weekly':    r.get('weekly',{}).get('trend','—'),
            'Has Option':r.get('option') is not None,
        })

df = pd.DataFrame(rows).sort_values('Score', ascending=False)
print(df.to_string(index=False))
# Out:
# Symbol  Score Conviction     Trend  RSI            Volume    Weekly  Has Option
#    BAC      8       HIGH     MIXED 34.1           NEUTRAL     MIXED        True
#    AAL      7   MODERATE   UPTREND 71.1      ACCUMULATION     MIXED       False
#     KO      7   MODERATE   UPTREND 65.8           NEUTRAL   UPTREND        True
#    DIS      7   MODERATE   UPTREND 38.8           NEUTRAL     MIXED        True
#   UBER      7   MODERATE     MIXED 18.3           NEUTRAL DOWNTREND       False
#    AMD      7   MODERATE   UPTREND 67.3           NEUTRAL   UPTREND       False
#      C      7   MODERATE     MIXED 45.1           NEUTRAL   UPTREND       False
#     MU      7   MODERATE   UPTREND 70.9 MILD_ACCUMULATION   UPTREND       False
#   AAPL      7   MODERATE   UPTREND 87.4           NEUTRAL   UPTREND       False
#     GS      7   MODERATE   UPTREND 67.7 MILD_ACCUMULATION   UPTREND       False
#   AMZN      7   MODERATE   UPTREND 46.7           NEUTRAL   UPTREND       False
#      F      6   MODERATE   UPTREND 76.5           NEUTRAL     MIXED       False
#    PFE      6   MODERATE     MIXED 52.3           NEUTRAL     MIXED        True
#   SOFI      6   MODERATE     MIXED 48.6           NEUTRAL DOWNTREND        True
#    XLF      6   MODERATE     MIXED 45.6           NEUTRAL     MIXED        True
#   INTC      6   MODERATE   UPTREND 57.0           NEUTRAL   UPTREND       False
#  GOOGL      6   MODERATE     MIXED 42.3           NEUTRAL   UPTREND       False
#      V      6   MODERATE   UPTREND 61.4           NEUTRAL     MIXED       False
#    UNH      6   MODERATE   UPTREND 60.8           NEUTRAL   UPTREND       False
#   MSFT      6   MODERATE     MIXED 49.7           NEUTRAL     MIXED       False
#   META      6   MODERATE     MIXED 62.4           NEUTRAL     MIXED       False
#   NVDA      6   MODERATE     MIXED 54.2           NEUTRAL   UPTREND       False
#    SPY      6   MODERATE   UPTREND 65.8           NEUTRAL   UPTREND       False
#    QQQ      6   MODERATE   UPTREND 69.7           NEUTRAL   UPTREND       False
#    NKE      5       NONE     MIXED 64.1           NEUTRAL     MIXED       False
#    JPM      5       NONE     MIXED 35.3           NEUTRAL     MIXED       False
#    JNJ      5       NONE     MIXED 63.4           NEUTRAL     MIXED       False
#   COST      5       NONE     MIXED 51.8           NEUTRAL     MIXED       False
#   PLTR      4       NONE DOWNTREND 47.3           NEUTRAL DOWNTREND       False
#      T      4       NONE DOWNTREND 41.7           NEUTRAL DOWNTREND       False
#    WFC      4       NONE DOWNTREND 37.8           NEUTRAL DOWNTREND       False
#     MA      3       NONE DOWNTREND 52.5           NEUTRAL DOWNTREND       False
#    XOM      3       NONE DOWNTREND 50.3           NEUTRAL     MIXED       False
#    CVX      3       NONE DOWNTREND 48.5           NEUTRAL     MIXED       False

# %%
# Cell 7 — Trade Journal (entry, exit, and re-entry)
import os
if os.path.exists("trade_journal.csv"):
    os.remove("trade_journal.csv")
    print("Journal cleared")

# Trade 1 — Original buy 5/26
trade_id_1 = log_entry(
    symbol         = "BAC",
    direction      = "BUY CALL",
    trade_type     = "SINGLE LEG",
    score          = 9,
    conviction     = "HIGH",
    market_regime  = "BULLISH",
    entry_premium  = 3.45,
    stop_price     = 2.24,
    target_price   = 6.04,
    time_stop_date = "2026-06-26",
    contracts      = 1,
    total_cost     = 345,
    notes          = "First live trade — entered 5/26"
)

log_exit(
    trade_id     = trade_id_1,
    exit_premium = 3.55,
    exit_reason  = "MANUAL",
    notes        = "Accidental exit 5/27 at open — limit sell error. Should have been stop limit."
)

# Trade 2 — Re-entry 5/27
trade_id_2 = log_entry(
    symbol         = "BAC",
    direction      = "BUY CALL",
    trade_type     = "SINGLE LEG",
    score          = 9,
    conviction     = "HIGH",
    market_regime  = "BULLISH",
    entry_premium  = 3.45,
    stop_price     = 2.24,
    target_price   = 6.04,
    time_stop_date = "2026-06-26",
    contracts      = 1,
    total_cost     = 345,
    notes          = "Re-entry 5/27 after accidental exit"
)

print(f"\nOpen trade ID: {trade_id_2}")
show_journal()
# Out:
# Journal cleared
#
#   ✓ Trade logged: BAC-202605272201
#     BAC BUY CALL | Entry: $3.45 | Stop: $2.24 | Target: $6.04
#     Contracts: 1 | Cost: $345 | Time stop: 2026-06-26
#
#   ✓ Trade closed: BAC-202605272201
#     Exit: $3.55 | Reason: MANUAL
#     P&L: $+10.00 (+2.9%) — WIN
#
#   ✓ Trade logged: BAC-202605272201
#     BAC BUY CALL | Entry: $3.45 | Stop: $2.24 | Target: $6.04
#     Contracts: 1 | Cost: $345 | Time stop: 2026-06-26
#
# Open trade ID: BAC-202605272201
#
# ──────────────────────────────────────────────────────────────
#   TRADE JOURNAL  |  2 trade(s)  |  Filter: ALL
# ──────────────────────────────────────────────────────────────
#   Open: 1  |  Wins: 1  |  Losses: 0  |  Win rate: 100.0%  |  Total P&L: $+10.00
# ──────────────────────────────────────────────────────────────
#
#   🟢 BAC-202605272201
#     BAC BUY CALL | Score: 9/12 | HIGH
#     Entry: $3.45 × 1 contracts = $345 | 2026-05-27 18:01 ET
#     Exit:  $3.55 | MANUAL | 2026-05-27 18:01 ET  P&L: $+10.00
#     Notes: Accidental exit 5/27 at open — limit sell error. Should have been stop limit.
#
#   🔵 BAC-202605272201
#     BAC BUY CALL | Score: 9/12 | HIGH
#     Entry: $3.45 × 1 contracts = $345 | 2026-05-27 18:01 ET
#     Stop: $2.24 | Target: $6.04 | Time stop: 2026-06-26
#     Notes: Re-entry 5/27 after accidental exit
#
# ──────────────────────────────────────────────────────────────

# %%
# Cell 9 — View journal anytime
show_journal()
# show_journal("OPEN")
# show_journal("WIN")
# Out:
# ──────────────────────────────────────────────────────────────
#   TRADE JOURNAL  |  2 trade(s)  |  Filter: ALL
# ──────────────────────────────────────────────────────────────
#   Open: 1  |  Wins: 1  |  Losses: 0  |  Win rate: 100.0%  |  Total P&L: $+10.00
# ──────────────────────────────────────────────────────────────
#
#   🔵 BAC-202605272150
#     BAC BUY CALL | Score: 9/12 | HIGH
#     Entry: $3.45 × 1 contracts = $345 | 2026-05-27 17:50 ET
#     Stop: $2.24 | Target: $6.04 | Time stop: 2026-06-26
#     Notes: Re-entry after accidental exit at 3.55 on 5/27 (limit sell error). Original entry 5/26 at 3.45, net difference +$9.92 after fees.
#
#   🟢 BAC-202605272154
#     BAC BUY CALL | Score: 9/12 | HIGH
#     Entry: $3.45 × 1 contracts = $345 | 2026-05-27 17:54 ET
#     Exit:  $3.55 | MANUAL | 2026-05-27 17:54 ET  P&L: $+10.00
#     Notes: Accidental exit — limit sell triggered at open. Should have been stop limit order.
#
# ──────────────────────────────────────────────────────────────
